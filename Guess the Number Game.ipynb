# %%
import random
Num=random.randrange(1,11)
print("Hi")
print('Lets play a game named "Guess the Number" ')
print()
start=input('Type "GO" to Start')
print("""Let me expline How to play first (O_o) 
               
               1#. I will think of a Number, It will be in the Range of 1-10.
               
               2#. You will get 6 chance to guess the Number.
               
               3#. Everytime you guess wrong, I will tell whether it is Great or Less than the 
               Number I taught in my mind. 
               
               4#. If you can't find the number 6 chance then you lost i won, If you found the 
               Number correctly You won i lost. """)
for i in range(1,7):
    
    print("Lets Start")
    print('''                                         
                                         CHANCE''',i)
    chance_1=int(input("What is the number? "))
    if(chance_1==Num):
        print("You Found the Number(T_T).")
        print("I hope you are good at Guessing... ")
        print("I Lost and You Won")
        if(i==i):
            break
            
    
  
          
          
    elif(chance_1>Num):
        print("Your Number is Greater than mine.")
        if(i==6):
            print("I Won and You Lost")
            
          
          
    elif(chance_1<Num):
        print('Your Number is less than mine.')
        if(i==6):
            print("I Won and You Lost")
            
            
again=input("Wants to Play Again? Y/N")
if again=="Y" or again=="y" or again=="Yes" or again=="yes":
  
    Num=random.randrange(1,11)
    run= True
    
else:
    run= False

while run==True:
    for i in range(1,7):
    
        print("Lets Start")
        print('''                                         
                                         CHANCE''',i)
        chance_1=int(input("What is the number? "))
        if(chance_1==Num):
            print("You Found the Number(T_T).")
            print("I hope you are good at Guessing... ")
            print("I Lost and You Won")
            if(i==i):
                break
            
    
  
          
          
        elif(chance_1>Num):
            print("Your Number is Greater than mine.")
            if(i==6):
                print("I Won and You Lost")
            
          
          
        elif(chance_1<Num):
            print('Your Number is less than mine.')
            if(i==6):
                print("I Won and You Lost")
            
    again=input("Wants to Play Again? Y/N")
    if again=="Y" or again=="y" or again=="Yes" or again=="yes":
        Num=random.randrange(1,11)
        run= True
    
    else:
        print("Bye......(X_X)")
        run= False
